# %%
import librosa
import matplotlib.pyplot as plt
import numpy as np
print('All imports working!')
# Out:
# All imports working!

# %%
# Load dog bark
audio_file = "../data/dog_bark.wav"
audio_data, sample_rate = librosa.load(audio_file)
print(f"Audio shape: {audio_data.shape}")
print(f"Sample rate: {sample_rate}")

# Plot waveform
plt.figure(figsize=(10, 4))
plt.plot(audio_data)
plt.title("Dog Bark Waveform")
plt.show()
# Out:
# Audio shape: (718242,)
# Sample rate: 22050
